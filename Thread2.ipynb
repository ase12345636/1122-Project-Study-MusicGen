# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd "/content/drive/MyDrive"

# %cd "1122-Project-Study-MusicGen/__MusicGen"

# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# /content/drive/MyDrive/1122-Project-Study-MusicGen/__MusicGen
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 18.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...

# %%
# !python Train_MusicGen_Test.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/1122-Project-Study-MusicGen/__MusicGen/Train_MusicGen_10M.py", line 14, in <module>
#     from MusicGenModel.MusicGen.MusicGen import MusicGen
#   File "/content/drive/MyDrive/1122-Project-Study-MusicGen/__MusicGen/MusicGenModel/MusicGen/MusicGen.py", line 6, in <module>
#     from ..DecoderModel.Decoder import Decoder
#   File "/content/drive/MyDrive/1122-Project-Study-MusicGen/__MusicGen/MusicGenModel/DecoderModel/Decoder.py", line 8, in <module>
#     from Config.Config import output_ntoken
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 975, in get_code
# ...

# %%
import os
import json
from pathlib import Path

text_folder_path = Path("Dataset/OriginalData/json/"+"test")
text_dirs = os.listdir(text_folder_path)
text_dirs.sort()


print(text_dirs[328])
json_file_path = text_folder_path/text_dirs[328]
json_data = json.load(open(json_file_path))
print(json_data["caption"])

print(text_dirs[202])
json_file_path = text_folder_path/text_dirs[202]
json_data = json.load(open(json_file_path))
print(json_data["caption"])

print(text_dirs[59])
json_file_path = text_folder_path/text_dirs[59]
json_data = json.load(open(json_file_path))
print(json_data["caption"])
# Out:
# Music_655.wav.json
# This is an advertisement jingle music piece. It is an instrumental piece. The main theme is being played by the piano while there is a synth string sound in the melodic background. There is an emotional, heart-touching atmosphere. This piece could be used in the soundtrack of a drama movie during scenes of tragedy. It could also work well as an advertisement jingle where there is an attempted appeal to emotion.
# Music_3832.wav.json
# The low quality recording features a drum & bass song that consists of a repetitive female vocal sound effect, growl synth bass, manic percussions, shimmering hi hats, punchy kick and snare hits and echoing synth pad. It sounds energetic, aggressive and manic - like something you would hear in underground clubs during the 00s.
# Music_2066.wav.json
# The low quality recording features a live performance that consists of bagpipes melodies. It sounds soulful, passionate, cultural and the recording is in mono and noisy.
